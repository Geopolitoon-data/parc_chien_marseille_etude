# %%
import folium
import seaborn as sns
from IPython.display import display
import pandas as pd

data = pd.read_excel("Raw_data.xlsx")

# Fonction pour créer la carte interactive
def create_marseille_map(data):
    # Définir les arrondissements uniques
    arrondissements_uniques = sorted(data['arrd'].unique())  # Trier les arrondissements
    palette = sns.color_palette("tab20", len(arrondissements_uniques)).as_hex()
    color_map = {arr: palette[i] for i, arr in enumerate(arrondissements_uniques)}  # Associer les couleurs

    # Centre de Marseille
    marseille_center = [43.2965, 5.37]
    m = folium.Map(location=marseille_center, zoom_start=12)

    # Ajouter les points sur la carte
    for i, row in data.iterrows():
        lat, lon = row['latitude'], row['longitude']
        arr = row['arrd']
        color = color_map[arr]
        folium.CircleMarker(
            location=[lat, lon],
            radius=8,
            color="black",
            weight=1,
            fill=True,
            fill_color=color,
            fill_opacity=0.9,
            popup=f"Arr. {arr} - {row['nom_jardin_parc']} - {row['equipement']}"
        ).add_to(m)

    # Ajouter une légende pour les couleurs
    legend_html = """
    <div style="
        position: fixed;
        bottom: 50px;
        left: 50px;
        width: 250px;
        height: auto;
        background-color: white;
        border:2px solid grey;
        z-index:9999;
        font-size:14px;
        padding: 10px;
        ">
        <b>Couleurs des arrondissements</b><br>
    """
    for arr, color in color_map.items():
        legend_html += f"<i style='background: {color}; width: 10px; height: 10px; display: inline-block;'></i> Arr. {arr}<br>"
    legend_html += "</div>"

    m.get_root().html.add_child(folium.Element(legend_html))
    return m

# %%
# Afficher la carte interactive
m = create_marseille_map(data)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_642be2be092f6af289201924e9ed4b8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px;
#         left: 50px;
#         width: 250px;
#         height: auto;
#         background-color: white;
#         border:2px solid grey;
#         z-index:9999;
#         font-size:14px;
#         padding: 10px;
#         &quot;&gt;
#         &lt;b&gt;Couleurs des arrondissements&lt;/b&gt;&lt;br&gt;
#     &lt;i style=&#x27;background: #1f77b4; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13003&lt;br&gt;&lt;i style=&#x27;background: #aec7e8; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13004&lt;br&gt;&lt;i style=&#x27;background: #ff7f0e; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13005&lt;br&gt;&lt;i style=&#x27;background: #ffbb78; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13006&lt;br&gt;&lt;i style=&#x27;background: #2ca02c; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13007&lt;br&gt;&lt;i style=&#x27;background: #98df8a; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13008&lt;br&gt;&lt;i style=&#x27;background: #d62728; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13009&lt;br&gt;&lt;i style=&#x27;background: #ff9896; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13010&lt;br&gt;&lt;i style=&#x27;background: #9467bd; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13011&lt;br&gt;&lt;i style=&#x27;background: #c5b0d5; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13012&lt;br&gt;&lt;i style=&#x27;background: #8c564b; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13013&lt;br&gt;&lt;i style=&#x27;background: #c49c94; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13014&lt;br&gt;&lt;i style=&#x27;background: #e377c2; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13015&lt;br&gt;&lt;i style=&#x27;background: #f7b6d2; width: 10px; height: 10px; display: inline-block;&#x27;&gt;&lt;/i&gt; Arr. 13016&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_642be2be092f6af289201924e9ed4b8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_642be2be092f6af289201924e9ed4b8e = L.map(
#                 &quot;map_642be2be092f6af289201924e9ed4b8e&quot;,
#                 {
#                     center: [43.2965, 5.37],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8688cc264ea477b1dbaa6d07cc77c86b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8688cc264ea477b1dbaa6d07cc77c86b.addTo(map_642be2be092f6af289201924e9ed4b8e);
#
#
#             var circle_marker_4df941a7093fddd60d3be6b3ca4f2fe8 = L.circleMarker(
#                 [43.3046829, 5.3953013],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#aec7e8&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_642be2be092f6af289201924e9ed4b8e);
#
#
#         var popup_96f4a1b7aaabdaba3285e562d838b309 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99c3b088d0ef033ac0f3a34f8289de18 = $(`&lt;div id=&quot;html_99c3b088d0ef033ac0f3a34f8289de18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arr. 13004 - Parc Longchamp - caniparc&lt;/div&gt;`)[0];
#                 popup_96f4a1b7aaabdaba3285e562d838b309.setContent(html_99c3b088d0ef033ac0f3a34f8289de18);
#
#
#
#         circle_marker_4df941a7093fddd60d3be6b3ca4f2fe8.bindPopup(popup_96f4a1b7aaabdaba3285e562d838b309)
#         ;
#
#
#
#
#             var circle_marker_f7631715d1ecd1a747b2bc57fd034d6e = L.circleMarker(
#                 [43.282552950631, 5.372271171314],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2ca02c&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_642be2be092f
